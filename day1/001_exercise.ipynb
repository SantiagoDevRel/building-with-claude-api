# %%
## Install depenedncies
# %pip install anthropic python-dotenv
# Out:
# Requirement already satisfied: anthropic in c:\users\santiago\appdata\local\programs\python\python312\lib\site-packages (0.85.0)
# Requirement already satisfied: python-dotenv in c:\users\santiago\appdata\local\programs\python\python312\lib\site-packages (1.2.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\santiago\appdata\local\programs\python\python312\lib\site-packages (from anthropic) (4.12.1)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\santiago\appdata\local\programs\python\python312\lib\site-packages (from anthropic) (1.9.0)
# Requirement already satisfied: docstring-parser<1,>=0.15 in c:\users\santiago\appdata\local\programs\python\python312\lib\site-packages (from anthropic) (0.17.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in c:\users\santiago\appdata\local\programs\python\python312\lib\site-packages (from anthropic) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\santiago\appdata\local\programs\python\python312\lib\site-packages (from anthropic) (0.13.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\santiago\appdata\local\programs\python\python312\lib\site-packages (from anthropic) (2.12.5)
# Requirement already satisfied: sniffio in c:\users\santiago\appdata\local\programs\python\python312\lib\site-packages (from anthropic) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in c:\users\santiago\appdata\local\programs\python\python312\lib\site-packages (from anthropic) (4.15.0)
# Requirement already satisfied: idna>=2.8 in c:\users\santiago\appdata\local\programs\python\python312\lib\site-packages (from anyio<5,>=3.5.0->anthropic) (3.11)
# Requirement already satisfied: certifi in c:\users\santiago\appdata\local\programs\python\python312\lib\site-packages (from httpx<1,>=0.25.0->anthropic) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in c:\users\santiago\appdata\local\programs\python\python312\lib\site-packages (from httpx<1,>=0.25.0->anthropic) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\santiago\appdata\local\programs\python\python312\lib\site-packages (from httpcore==1.*->httpx<1,>=0.25.0->anthropic) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\santiago\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3,>=1.9.0->anthropic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\santiago\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3,>=1.9.0->anthropic) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\santiago\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3,>=1.9.0->anthropic) (0.4.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
## Import and init modules
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()
client = Anthropic()

## Setup model
model = "claude-sonnet-4-0"
messages_list = []

## Define functions
## Chat
def chat(messages_list):
    message = client.messages.create(
        model = model,
        max_tokens = 1000,
        messages = messages_list
    )
    return message.content[0].text

## Add user & assistant msgs
def add_user_message(messages_list, msg):
    formatted_user_msg = {"role":"user", "content":msg}
    messages_list.append(formatted_user_msg)

def add_assistant_message(messages_list, msg):
    formatted_assistant_msg = {"role":"assistant", "content":msg}
    messages_list.append(formatted_assistant_msg)  

## Input function
while True:
   user_input = input("You: ")
   # Type quit to exit the loop
   if user_input.lower() == "quit":
        break

   add_user_message(messages_list, user_input)
   response = chat(messages_list)
   add_assistant_message(messages_list, response)
   print("-----")
   print(f"response {(len(messages_list) / 2)} \n{response}")
   print("-----")
# Out:
# -----
# response 1.0
# Hello! Nice to meet you. How are you doing today?
# -----
# -----
# response 2.0
# Here are some strategies to earn more Avianca LifeMiles and work toward Star Alliance Gold status:
#
# **Avianca LifeMiles earning options:**
#
# 1. **Fly Avianca or Star Alliance partners** - Focus flights on these airlines when possible
# 2. **Credit card partnerships** - Look for Avianca co-branded cards or cards that transfer points to LifeMiles
# 3. **Hotel partnerships** - Stay at partner hotels and credit miles to LifeMiles
# 4. **Car rental partners** - Use Avianca's car rental partners
# 5. **Shopping portals** - Use Avianca's online shopping portal
# 6. **Dining programs** - If available in your region
#
# **Status shortcuts to consider:**
#
# 1. **Status matches** - If you have status with another airline, Avianca sometimes offers status matches or challenges
# 2. **Elite qualifying promotions** - Watch for double/bonus elite qualifying mile promotions
# 3. **Consider other Star Alliance programs** - Sometimes it's easier to earn status with United, Lufthansa, or other Star Alliance carriers depending on your location and travel patterns
#
# **What's your timeline and location?** This would help me give more specific advice. Also, do you know how many elite qualifying miles you need for Avianca Gold status? The requirements vary by program.
#
# The key is often finding the most efficient path based on your travel patterns and location.
# -----
# -----
# response 3.0
# Great! Being in Colombia gives you some good advantages for earning Avianca LifeMiles:
#
# **Colombia-specific opportunities:**
#
# 1. **Avianca Credit Cards** - Check with Colombian banks (like Banco de Bogotá, Bancolombia) for Avianca co-branded credit cards that earn LifeMiles on purchases
#
# 2. **Local partnerships** - Avianca has partnerships with Colombian retailers, restaurants, and service providers where you can earn miles
#
# 3. **Domestic flights** - Flying Avianca domestically within Colombia can be cost-effective for earning elite qualifying miles
#
# 4. **Regional routes** - Consider short regional flights to Central America or other South American countries on Avianca
#
# **Status requirements reminder:**
# - Avianca LifeMiles Gold typically requires around 40,000-50,000 elite qualifying miles OR a certain number of segments
# - Check if there are any current promotions for reduced requirements
#
# **Alternative strategy:**
# Since you're in Colombia, you might also consider:
# - **Copa Airlines** (Star Alliance) - they have a strong presence in Latin America
# - **LATAM Pass** status matches (though they left Star Alliance)
#
# **Quick questions:**
# - Do you travel frequently for work or leisure?
# - What's your typical annual flight budget?
# - Are you open to taking some additional flights specifically for status?
#
# This will help me suggest the most practical path forward!
# -----
# -----
# response 4.0
# Perfect! Here are some practical next steps for you in Colombia:
#
# **Immediate actions:**
# 1. **Get an Avianca credit card** - Apply with Bancolombia or Banco de Bogotá for their Avianca cards. Use it for all purchases to rack up miles quickly
#
# 2. **Plan some domestic flights** - Book a few domestic Colombian routes (Bogotá-Medellín, Cartagena, etc.) to build up elite qualifying miles affordably
#
# 3. **Check for status promotions** - Avianca sometimes runs promotions where you need fewer miles for status or get bonus elite miles
#
# **Strategic flying:**
# - **Central America trips** - Guatemala, Costa Rica, Panama are relatively affordable from Colombia on Avianca
# - **Weekend getaways** - Short trips to Ecuador or other nearby destinations
# - **Route planning** - Sometimes connecting flights earn more elite miles than direct ones
#
# **Sign up for everything:**
# - Avianca shopping portal
# - Hotel partnerships (check which hotel chains credit to LifeMiles)
# - Any dining programs available in Colombia
#
# You'll probably need around 35,000-45,000 more elite qualifying miles for Gold status. With strategic planning and the credit card, this could be achievable in 6-12 months depending on your travel frequency.
#
# Want me to help you research specific routes or partnerships?
# -----
